# %%
# !pip install google_colab_shell
from google_colab_shell import getshell

getshell()
# Out:
# Collecting google_colab_shell
#   Downloading google-colab-shell-0.2.tar.gz (4.2 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: google_colab_shell
#   Building wheel for google_colab_shell (setup.py) ... done
#   Created wheel for google_colab_shell: filename=google_colab_shell-0.2-py3-none-any.whl size=4107 sha256=216a8e95188ac22111233315c42bbbacd97fee3ff4b0b791cc9d45842d175bf8
#   Stored in directory: /root/.cache/pip/wheels/f9/36/65/95dd4599be065418a9fe1f482674c8e716ce540f3f484681d2
# Successfully built google_colab_shell
# Installing collected packages: google_colab_shell
# Successfully installed google_colab_shell-0.2
# <!--https://github.com/singhsidhukuldeep/Google-Colab-Shell/-->
# <!--Using JS/CSS from official sources with backups in-case :)-->
# <div id=colab_shell></div>
# <script src="https://code.jquery.com/jquery-latest.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/jquery.terminal/js/jquery.terminal.min.js"></script>
# <link href="https://cdn.jsdelivr.net/npm/jquery.terminal/css/jquery.terminal.min.css" rel="stylesheet"/>
# <script>
#    $('#colab_shell').terminal(async function(command) {
#        if (command !== '') {
#            try {
#                let res = await google.colab.kernel.invokeFunction('shell', [command])
#                let out = res.data['application/json'][0]
#                this.echo(new String(out))
#            } catch(e) {
#                this.error(new String(e));
#            }
#        } else {
#            this.echo(
#              //   '>>Empty Command<<\n'+
#              //   'If you can afford use Google Colab Pro'
#                );
#        }
#    }, {
#        greetings: 'Welcome to Google Colab Shell\n'+
#          'If you can afford, please use Google Colab Pro ( https://colab.research.google.com/signup )\n'+
#          '⭐ STAR the repo ⭐\n https://github.com/singhsidhukuldeep/Google-Colab-Shell\n\n',
#        name: 'colab_shell',
#        height: 400,
#        prompt: '█$ colab>>\t'
#    });
# </script>

# %%
getshell()
# Out:
# <!--https://github.com/singhsidhukuldeep/Google-Colab-Shell/-->
# <!--Using JS/CSS from official sources with backups in-case :)-->
# <div id=colab_shell></div>
# <script src="https://code.jquery.com/jquery-latest.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/jquery.terminal/js/jquery.terminal.min.js"></script>
# <link href="https://cdn.jsdelivr.net/npm/jquery.terminal/css/jquery.terminal.min.css" rel="stylesheet"/>
# <script>
#    $('#colab_shell').terminal(async function(command) {
#        if (command !== '') {
#            try {
#                let res = await google.colab.kernel.invokeFunction('shell', [command])
#                let out = res.data['application/json'][0]
#                this.echo(new String(out))
#            } catch(e) {
#                this.error(new String(e));
#            }
#        } else {
#            this.echo(
#              //   '>>Empty Command<<\n'+
#              //   'If you can afford use Google Colab Pro'
#                );
#        }
#    }, {
#        greetings: 'Welcome to Google Colab Shell\n'+
#          'If you can afford, please use Google Colab Pro ( https://colab.research.google.com/signup )\n'+
#          '⭐ STAR the repo ⭐\n https://github.com/singhsidhukuldeep/Google-Colab-Shell\n\n',
#        name: 'colab_shell',
#        height: 400,
#        prompt: '█$ colab>>\t'
#    });
# </script>

# %%
import requests
import json
from pprint import pprint

# get secret from Colab
from google.colab import userdata
token = userdata.get('11222')

# initialize request parameters
url = 'https://api.github.com/user'
headers = {'Authorization': 'Bearer ' + token}

# send request to GitHub
r = requests.get(url, headers=headers)

# print initial responses
print(r.status_code)
print(r.text)

r_json = json.loads(r.text)
pprint(r_json)
# Out:
# 200
# {"login":"KriedF","id":151970557,"node_id":"U_kgDOCQ7i_Q","avatar_url":"https://avatars.githubusercontent.com/u/151970557?v=4","gravatar_id":"","url":"https://api.github.com/users/KriedF","html_url":"https://github.com/KriedF","followers_url":"https://api.github.com/users/KriedF/followers","following_url":"https://api.github.com/users/KriedF/following{/other_user}","gists_url":"https://api.github.com/users/KriedF/gists{/gist_id}","starred_url":"https://api.github.com/users/KriedF/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/KriedF/subscriptions","organizations_url":"https://api.github.com/users/KriedF/orgs","repos_url":"https://api.github.com/users/KriedF/repos","events_url":"https://api.github.com/users/KriedF/events{/privacy}","received_events_url":"https://api.github.com/users/KriedF/received_events","type":"User","site_admin":false,"name":null,"company":null,"blog":"","location":null,"email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":2,"public_gists":0,"followers":0,"following":1,"created_at":"2023-11-24T21:35:24Z","updated_at":"2023-11-26T15:22:57Z"}
# {'avatar_url': 'https://avatars.githubusercontent.com/u/151970557?v=4',
#  'bio': None,
#  'blog': '',
#  'company': None,
#  'created_at': '2023-11-24T21:35:24Z',
#  'email': None,
#  'events_url': 'https://api.github.com/users/KriedF/events{/privacy}',
#  'followers': 0,
#  'followers_url': 'https://api.github.com/users/KriedF/followers',
#  'following': 1,
#  'following_url': 'https://api.github.com/users/KriedF/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/KriedF/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/KriedF',
#  'id': 151970557,
#  'location': None,
#  'login': 'KriedF',
#  'name': None,
#  'node_id': 'U_kgDOCQ7i_Q',
#  'organizations_url': 'https://api.github.com/users/KriedF/orgs',
#  'public_gists': 0,
#  'public_repos': 2,
#  'received_events_url': 'https://api.github.com/users/KriedF/received_events',
#  'repos_url': 'https://api.github.com/users/KriedF/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/KriedF/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/KriedF/subscriptions',
#  'twitter_username': None,
#  'type': 'User',
#  'updated_at': '2023-11-26T15:22:57Z',
#  'url': 'https://api.github.com/users/KriedF'}
